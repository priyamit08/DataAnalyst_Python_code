# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
# Folder path: 
path = r'/Users/priyankamittal/Desktop/Data Analytics/CareerFoundry/Immersion/Python/07-2023 Instacart Basket Analysis Copy'

# %%
# Import orders_products_combined.pkl
orders_products_combined = pd.read_pickle(r'/Users/priyankamittal/Desktop/Data Analytics/CareerFoundry/Immersion/Python/07-2023 Instacart Basket Analysis Copy/Data/Prepared Data/orders_products_combined.pkl')

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
# Import products.csv
df_prods = pd.read_csv(os.path.join(path,'Data','Orginal Data','products.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# # 03 Task 4.6

# %%
# Step 4. Check the shape of the imported dataframe (it should be the same as the one you exported:
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
### Observations: Common ground found under 'product_id'
orders_products_combined = orders_products_combined.drop(columns = ['_merge'])

# %%
orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
##Merging the ords_prods_combined df with the df_prods via the product_id column
df_merged = orders_products_combined.merge(df_prods,on = ['product_id'], indicator = True)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
#Checking the values(frequency) in the _merge column
df_merged['_merge'].value_counts()
# Out:
# both          32434212
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
#Checking the merged shape
df_merged.shape
# Out:
# (32434212, 15)

# %%
#Exporting the newly merged dataframe; Using pickle format due to size
df_merged.to_csv(os.path.join(path,'Data','Prepared Data','orders_products_merged.csv'))
